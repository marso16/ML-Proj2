# %%
import os 
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import keras 
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report
from imblearn.over_sampling import SMOTE
from tensorflow.keras.applications import ResNet50
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, GlobalAveragePooling2D, Flatten, BatchNormalization, Dense, Input, Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.optimizers import RMSprop
from keras.optimizers import RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
images = []
labels = []
dataset_path = 'dataset'
for subfolder in tqdm(os.listdir(dataset_path)):
    subfolder_path = os.path.join(dataset_path, subfolder)
    for folder in os.listdir(subfolder_path):
        subfolder_path2=os.path.join(subfolder_path,folder)
        for image_filename in os.listdir(subfolder_path2):
            image_path = os.path.join(subfolder_path2, image_filename)
            images.append(image_path)
            labels.append(folder)
df = pd.DataFrame({'image': images, 'label': labels})
df
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  6.47it/s]
#                                                   image             label
# 0                 dataset\test\MildDemented\26 (19).jpg      MildDemented
# 1                 dataset\test\MildDemented\26 (20).jpg      MildDemented
# 2                 dataset\test\MildDemented\26 (21).jpg      MildDemented
# 3                 dataset\test\MildDemented\26 (22).jpg      MildDemented
# 4                 dataset\test\MildDemented\26 (23).jpg      MildDemented
# ...                                                 ...               ...
# 6395  dataset\train\VeryMildDemented\verymildDem995.jpg  VeryMildDemented
# 6396  dataset\train\VeryMildDemented\verymildDem996.jpg  VeryMildDemented
# 6397  dataset\train\VeryMildDemented\verymildDem997.jpg  VeryMildDemented
# 6398  dataset\train\VeryMildDemented\verymildDem998.jpg  VeryMildDemented
# 6399  dataset\train\VeryMildDemented\verymildDem999.jpg  VeryMildDemented
#
# [6400 rows x 2 columns]

# %%
plt.figure(figsize=(4, 4))
class_counts = df['label'].value_counts()
labels = class_counts.index
sizes = class_counts.values
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('Set1'))
plt.title('Distribution of Classes', fontsize=20)
plt.show()

# %%
for label, size in zip(labels, sizes):
    print(f"Label: {label}, Size: {size}")
# Out:
# Label: NonDemented, Size: 3200
# Label: VeryMildDemented, Size: 2240
# Label: MildDemented, Size: 896
# Label: ModerateDemented, Size: 64

# %%
class_num=np.sort(['MildDemented','ModerateDemented','NonDemented','VeryMildDemented'])
class_num
# Out:
# array(['MildDemented', 'ModerateDemented', 'NonDemented',
#        'VeryMildDemented'], dtype='<U16')

# %%
# Sample image for each class
def load_and_preprocess_image(image_path, target_size=(224, 224)):
    img = cv2.imread(image_path)
    img = cv2.resize(img, target_size)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    return img

plt.figure(figsize=(12, 8))
for i, class_name in enumerate(class_num):
    class_images = df[df['label'] == class_name]['image'].sample(3, replace=True).tolist()
    for j, img_path in enumerate(class_images):
        plt.subplot(4, 3, i*3 + j + 1) 
        img = load_and_preprocess_image(img_path)
        plt.imshow(img)
        plt.title(f'{class_name} - Sample {j+1}')
        plt.axis('off')
plt.tight_layout()
plt.show()

# %%
sizes = []
for img in df['image']:
    if os.path.exists(img): # Check if the file exists
        img_shape = cv2.imread(img).shape
        if img_shape is not None: # Check if the image was read successfully
            sizes.append(img_shape)
        else:
            print(f"Failed to read image: {img}")
    else:
        print(f"File does not exist: {img}")

sizes_df = pd.DataFrame(sizes, columns=['Height', 'Width', 'Channels'])

# Convert infinite values to NaN in sizes_df as well, just in case
sizes_df.replace([np.inf, -np.inf], np.nan, inplace=True)

plt.figure(figsize=(6, 4))
sns.histplot(sizes_df['Height'], kde=True, color='blue', label='Height', alpha=0.7)
sns.histplot(sizes_df['Width'], kde=True, color='orange', label='Width', alpha=0.7)
plt.title('Image Size Distribution')
plt.xlabel('Size')
plt.legend()
plt.show()
# Out:
# C:\Users\marck\anaconda3\envs\ML\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\marck\anaconda3\envs\ML\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
Size=(176,176)
work_dr = ImageDataGenerator(
    rescale=1./255,
    rotation_range=10,
    shear_range=0.2,
    horizontal_flip=True,
    vertical_flip=True
)
# enhancing model generalization
train_data_gen = work_dr.flow_from_dataframe(df,x_col='image',y_col='label', target_size=Size, batch_size=6500, shuffle=False)
# Out:
# Found 6400 validated image filenames belonging to 4 classes.

# %%
train_data, train_labels = train_data_gen.next()

# %%
sm = SMOTE(random_state=42)
train_data, train_labels = sm.fit_resample(train_data.reshape(-1, 176 * 176 * 3), train_labels)
train_data = train_data.reshape(-1, 176,176, 3)
print(train_data.shape, train_labels.shape)
# Out:
# (12800, 176, 176, 3) (12800, 4)

# %%
original_labels = np.argmax(train_labels, axis=1)
df_resampled = pd.DataFrame({'label': original_labels})
class_counts_resampled = df_resampled['label'].value_counts()

# %%
labels = ['MildDemented','ModerateDemented','NonDemented','VeryMildDemented']
sizes = class_counts_resampled.values

assert len(labels) == len(sizes), "Length mismatch between labels and sizes"

class_distribution_table = pd.DataFrame({'Class': labels, 'Count': sizes})

plt.figure(figsize=(6, 4))
table = plt.table(cellText=class_distribution_table.values,
                  colLabels=class_distribution_table.columns,
                  cellLoc='center', loc='center', bbox=[0, 0, 1, 1])

table.auto_set_font_size(False)
table.set_fontsize(12)
table.scale(1.2, 1.2) 

for (i, j), cell in table.get_celld().items():
    if i == 0:
        cell.set_text_props(fontweight='bold')

plt.axis('off')
plt.title('Class Distribution after SMOTE', fontsize=16)
plt.show()

# %%
X_train, X_test1, y_train, y_test1 = train_test_split(train_data,train_labels, test_size=0.3, random_state=42,shuffle=True,stratify=train_labels)
X_val, X_test, y_val, y_test = train_test_split(X_test1,y_test1, test_size=0.5, random_state=42,shuffle=True,stratify=y_test1)
print('X_train shape is ' , X_train.shape)
print('X_test shape is ' , X_test.shape)
print('X_val shape is ' , X_val.shape)
print('y_train shape is ' , y_train.shape)
print('y_test shape is ' , y_test.shape)
print('y_val shape is ' , y_val.shape)
# Out:
# X_train shape is  (8960, 176, 176, 3)
# X_test shape is  (1920, 176, 176, 3)
# X_val shape is  (1920, 176, 176, 3)
# y_train shape is  (8960, 4)
# y_test shape is  (1920, 4)
# y_val shape is  (1920, 4)

# %%
plt.figure(figsize=(12, 6))
for i in range(5):
    plt.subplot(2, 5, i + 1)
    plt.imshow(X_train[i])
    plt.title(f'Augmented\n{class_num[np.argmax(y_train[i])]}')
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Models**

# %% [markdown]
# # InceptionV3

# %%
base_model = tf.keras.applications.InceptionV3(input_shape=(176,176,3),include_top=False,weights='imagenet')
base_model.trainable = False
model_Inception=keras.models.Sequential()
model_Inception.add(base_model)
model_Inception.add(keras.layers.Dropout(.5))
model_Inception.add(keras.layers.GlobalAveragePooling2D()) 
model_Inception.add(keras.layers.Flatten()) 
model_Inception.add(keras.layers.BatchNormalization())
model_Inception.add(keras.layers.Dense(512,activation=tf.nn.relu))
model_Inception.add(keras.layers.BatchNormalization())
model_Inception.add(keras.layers.Dropout(.5))
model_Inception.add(keras.layers.Dense(256,activation=tf.nn.relu))
model_Inception.add(keras.layers.BatchNormalization())
model_Inception.add(keras.layers.Dropout(.5))
model_Inception.add(keras.layers.Dense(128,activation=tf.nn.relu))
model_Inception.add(keras.layers.BatchNormalization())
model_Inception.add(keras.layers.Dropout(.5))
model_Inception.add(keras.layers.Dense(64,activation=tf.nn.relu))
model_Inception.add(keras.layers.BatchNormalization())
model_Inception.add(keras.layers.Dropout(.5))
model_Inception.add(keras.layers.BatchNormalization())
model_Inception.add(keras.layers.Dense(4, activation=tf.nn.softmax))
model_Inception.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 4, 4, 2048)        21802784
#
#  dropout (Dropout)           (None, 4, 4, 2048)        0
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  batch_normalization_94 (Bat  (None, 2048)             8192
#  chNormalization)
#
#  dense (Dense)               (None, 512)               1049088
#
#  batch_normalization_95 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  batch_normalization_96 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  batch_normalization_97 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  batch_normalization_98 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  batch_normalization_99 (Bat  (None, 64)               256
#  chNormalization)
#
#  dense_4 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 23,036,900
# Trainable params: 1,227,972
# Non-trainable params: 21,808,928
# _________________________________________________________________

# %%
checkpoint_cb = ModelCheckpoint("inception.h5", save_best_only=True)
early_stopping_cb = EarlyStopping(patience=10, restore_best_weights=True)

optimizer_rmsprop = RMSprop(learning_rate=0.001)  # You can adjust the learning rate if needed
model_Inception.compile(optimizer=optimizer_rmsprop, loss='categorical_crossentropy', metrics=['accuracy'])
hist = model_Inception.fit(X_train, y_train, epochs=50, validation_data=(X_val, y_val), callbacks=[checkpoint_cb, early_stopping_cb], batch_size=128)
# Out:
# Epoch 1/50
# 70/70 [==============================] - 141s 2s/step - loss: 1.4893 - accuracy: 0.3760 - val_loss: 1.1388 - val_accuracy: 0.4891
# Epoch 2/50
# 70/70 [==============================] - 128s 2s/step - loss: 1.0641 - accuracy: 0.5256 - val_loss: 0.9180 - val_accuracy: 0.5896
# Epoch 3/50
# 70/70 [==============================] - 126s 2s/step - loss: 0.8855 - accuracy: 0.5967 - val_loss: 0.7646 - val_accuracy: 0.6448
# Epoch 4/50
# 70/70 [==============================] - 130s 2s/step - loss: 0.7950 - accuracy: 0.6305 - val_loss: 0.6920 - val_accuracy: 0.6719
# Epoch 5/50
# 70/70 [==============================] - 123s 2s/step - loss: 0.7293 - accuracy: 0.6633 - val_loss: 0.6586 - val_accuracy: 0.6901
# Epoch 6/50
# 70/70 [==============================] - 129s 2s/step - loss: 0.6836 - accuracy: 0.6906 - val_loss: 0.6209 - val_accuracy: 0.7005
# Epoch 7/50
# 70/70 [==============================] - 127s 2s/step - loss: 0.6569 - accuracy: 0.7039 - val_loss: 0.6043 - val_accuracy: 0.7146
# Epoch 8/50
# 70/70 [==============================] - 126s 2s/step - loss: 0.6267 - accuracy: 0.7116 - val_loss: 0.5973 - val_accuracy: 0.7271
# Epoch 9/50
# 70/70 [==============================] - 128s 2s/step - loss: 0.6069 - accuracy: 0.7270 - val_loss: 0.5740 - val_accuracy: 0.7318
# Epoch 10/50
# 70/70 [==============================] - 126s 2s/step - loss: 0.5765 - accuracy: 0.7469 - val_loss: 0.5519 - val_accuracy: 0.7516
# Epoch 11/50
# 70/70 [==============================] - 126s 2s/step - loss: 0.5490 - accuracy: 0.7563 - val_loss: 0.5304 - val_accuracy: 0.7500
# Epoch 12/50
# 70/70 [==============================] - 126s 2s/step - loss: 0.5320 - accuracy: 0.7682 - val_loss: 0.5290 - val_accuracy: 0.7563
# Epoch 13/50
# 70/70 [==============================] - 127s 2s/step - loss: 0.5112 - accuracy: 0.7792 - val_loss: 0.5046 - val_accuracy: 0.7740
# Epoch 14/50
# 70/70 [==============================] - 126s 2s/step - loss: 0.4803 - accuracy: 0.7983 - val_loss: 0.4947 - val_accuracy: 0.7745
# Epoch 15/50
# 70/70 [==============================] - 126s 2s/step - loss: 0.4626 - accuracy: 0.8042 - val_loss: 0.5078 - val_accuracy: 0.7729
# Epoch 16/50
# 70/70 [==============================] - 128s 2s/step - loss: 0.4449 - accuracy: 0.8157 - val_loss: 0.4863 - val_accuracy: 0.7766
# Epoch 17/50
# 70/70 [==============================] - 126s 2s/step - loss: 0.4231 - accuracy: 0.8296 - val_loss: 0.4935 - val_accuracy: 0.7865
# Epoch 18/50
# 70/70 [==============================] - 127s 2s/step - loss: 0.4040 - accuracy: 0.8390 - val_loss: 0.4839 - val_accuracy: 0.7979
# Epoch 19/50
# 70/70 [==============================] - 127s 2s/step - loss: 0.3955 - accuracy: 0.8465 - val_loss: 0.4541 - val_accuracy: 0.8109
# Epoch 20/50
# 70/70 [==============================] - 126s 2s/step - loss: 0.3879 - accuracy: 0.8485 - val_loss: 0.4750 - val_accuracy: 0.7958
# Epoch 21/50
# 70/70 [==============================] - 127s 2s/step - loss: 0.3653 - accuracy: 0.8581 - val_loss: 0.4496 - val_accuracy: 0.8094
# Epoch 22/50
# 70/70 [==============================] - 128s 2s/step - loss: 0.3421 - accuracy: 0.8680 - val_loss: 0.4450 - val_accuracy: 0.8177
# Epoch 23/50
# 70/70 [==============================] - 126s 2s/step - loss: 0.3484 - accuracy: 0.8633 - val_loss: 0.4494 - val_accuracy: 0.8073
# Epoch 24/50
# 70/70 [==============================] - 127s 2s/step - loss: 0.3259 - accuracy: 0.8773 - val_loss: 0.4396 - val_accuracy: 0.8208
# Epoch 25/50
# 70/70 [==============================] - 126s 2s/step - loss: 0.3106 - accuracy: 0.8783 - val_loss: 0.4542 - val_accuracy: 0.8240
# Epoch 26/50
# 70/70 [==============================] - 126s 2s/step - loss: 0.3012 - accuracy: 0.8836 - val_loss: 0.4562 - val_accuracy: 0.8203
# Epoch 27/50
# 70/70 [==============================] - 127s 2s/step - loss: 0.2826 - accuracy: 0.8914 - val_loss: 0.4302 - val_accuracy: 0.8344
# Epoch 28/50
# 70/70 [==============================] - 127s 2s/step - loss: 0.2954 - accuracy: 0.8926 - val_loss: 0.4171 - val_accuracy: 0.8391
# Epoch 29/50
# 70/70 [==============================] - 127s 2s/step - loss: 0.2684 - accuracy: 0.9003 - val_loss: 0.4225 - val_accuracy: 0.8365
# Epoch 30/50
# 70/70 [==============================] - 126s 2s/step - loss: 0.2619 - accuracy: 0.9064 - val_loss: 0.4532 - val_accuracy: 0.8276
# Epoch 31/50
# 70/70 [==============================] - 126s 2s/step - loss: 0.2596 - accuracy: 0.9057 - val_loss: 0.4324 - val_accuracy: 0.8344
# Epoch 32/50
# 70/70 [==============================] - 128s 2s/step - loss: 0.2401 - accuracy: 0.9112 - val_loss: 0.4608 - val_accuracy: 0.8292
# Epoch 33/50
# 70/70 [==============================] - 125s 2s/step - loss: 0.2366 - accuracy: 0.9118 - val_loss: 0.4329 - val_accuracy: 0.8344
# Epoch 34/50
# 70/70 [==============================] - 126s 2s/step - loss: 0.2270 - accuracy: 0.9173 - val_loss: 0.4175 - val_accuracy: 0.8401
# Epoch 35/50
# 70/70 [==============================] - 127s 2s/step - loss: 0.2300 - accuracy: 0.9169 - val_loss: 0.4331 - val_accuracy: 0.8359
# Epoch 36/50
# 70/70 [==============================] - 126s 2s/step - loss: 0.2209 - accuracy: 0.9171 - val_loss: 0.4332 - val_accuracy: 0.8375
# Epoch 37/50
# 70/70 [==============================] - 126s 2s/step - loss: 0.2171 - accuracy: 0.9237 - val_loss: 0.4332 - val_accuracy: 0.8349
# Epoch 38/50
# 70/70 [==============================] - 126s 2s/step - loss: 0.2106 - accuracy: 0.9235 - val_loss: 0.4254 - val_accuracy: 0.8391

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(hist.history['loss'], label='Train')
plt.plot(hist.history['val_loss'], label='Validation')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(hist.history['accuracy'], label='Train')
plt.plot(hist.history['val_accuracy'], label='Validation')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
y_pred = model_Inception.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Calculate the confusion matrix
conf_mat = confusion_matrix(y_true_classes, y_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues', xticklabels=class_num, yticklabels=class_num)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 60/60 [==============================] - 23s 391ms/step

# %%
score, acc= model_Inception.evaluate(X_test,y_test)
print('Test Loss =', score)
print('Test Accuracy =', acc)
# Out:
# 60/60 [==============================] - 26s 414ms/step - loss: 0.4490 - accuracy: 0.8245
# Test Loss = 0.4489593207836151
# Test Accuracy = 0.8244791626930237

# %% [markdown]
# # Autoencoders
