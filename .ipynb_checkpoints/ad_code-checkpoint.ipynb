# %%
import os 
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import keras 
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report
from imblearn.over_sampling import SMOTE
from tensorflow.keras.applications import ResNet50
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, GlobalAveragePooling2D, Flatten, BatchNormalization, Dense
from tensorflow.keras.optimizers import RMSprop
from keras.optimizers import RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
images = []
labels = []
dataset_path = 'dataset'
for subfolder in tqdm(os.listdir(dataset_path)):
    subfolder_path = os.path.join(dataset_path, subfolder)
    for folder in os.listdir(subfolder_path):
        subfolder_path2=os.path.join(subfolder_path,folder)
        for image_filename in os.listdir(subfolder_path2):
            image_path = os.path.join(subfolder_path2, image_filename)
            images.append(image_path)
            labels.append(folder)
df = pd.DataFrame({'image': images, 'label': labels})
df
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 77.13it/s]
#                                                   image             label
# 0                 dataset\test\MildDemented\26 (19).jpg      MildDemented
# 1                 dataset\test\MildDemented\26 (20).jpg      MildDemented
# 2                 dataset\test\MildDemented\26 (21).jpg      MildDemented
# 3                 dataset\test\MildDemented\26 (22).jpg      MildDemented
# 4                 dataset\test\MildDemented\26 (23).jpg      MildDemented
# ...                                                 ...               ...
# 6395  dataset\train\VeryMildDemented\verymildDem995.jpg  VeryMildDemented
# 6396  dataset\train\VeryMildDemented\verymildDem996.jpg  VeryMildDemented
# 6397  dataset\train\VeryMildDemented\verymildDem997.jpg  VeryMildDemented
# 6398  dataset\train\VeryMildDemented\verymildDem998.jpg  VeryMildDemented
# 6399  dataset\train\VeryMildDemented\verymildDem999.jpg  VeryMildDemented
#
# [6400 rows x 2 columns]

# %%
plt.figure(figsize=(4, 4))
class_counts = df['label'].value_counts()
labels = class_counts.index
sizes = class_counts.values
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('Set1'))
plt.title('Distribution of Classes', fontsize=20)
plt.show()

# %%
for label, size in zip(labels, sizes):
    print(f"Label: {label}, Size: {size}")
# Out:
# Label: NonDemented, Size: 3200
# Label: VeryMildDemented, Size: 2240
# Label: MildDemented, Size: 896
# Label: ModerateDemented, Size: 64

# %%
class_num=np.sort(['MildDemented','ModerateDemented','NonDemented','VeryMildDemented'])
class_num
# Out:
# array(['MildDemented', 'ModerateDemented', 'NonDemented',
#        'VeryMildDemented'], dtype='<U16')

# %%
# Sample image for each class
def load_and_preprocess_image(image_path, target_size=(224, 224)):
    img = cv2.imread(image_path)
    img = cv2.resize(img, target_size)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    return img

plt.figure(figsize=(12, 8))
for i, class_name in enumerate(class_num):
    class_images = df[df['label'] == class_name]['image'].sample(3, replace=True).tolist()
    for j, img_path in enumerate(class_images):
        plt.subplot(4, 3, i*3 + j + 1) 
        img = load_and_preprocess_image(img_path)
        plt.imshow(img)
        plt.title(f'{class_name} - Sample {j+1}')
        plt.axis('off')
plt.tight_layout()
plt.show()

# %%
sizes = []
for img in df['image']:
    if os.path.exists(img): # Check if the file exists
        img_shape = cv2.imread(img).shape
        if img_shape is not None: # Check if the image was read successfully
            sizes.append(img_shape)
        else:
            print(f"Failed to read image: {img}")
    else:
        print(f"File does not exist: {img}")

sizes_df = pd.DataFrame(sizes, columns=['Height', 'Width', 'Channels'])

# Convert infinite values to NaN in sizes_df as well, just in case
sizes_df.replace([np.inf, -np.inf], np.nan, inplace=True)

plt.figure(figsize=(6, 4))
sns.histplot(sizes_df['Height'], kde=True, color='blue', label='Height', alpha=0.7)
sns.histplot(sizes_df['Width'], kde=True, color='orange', label='Width', alpha=0.7)
plt.title('Image Size Distribution')
plt.xlabel('Size')
plt.legend()
plt.show()
# Out:
# C:\Users\marck\anaconda3\envs\ML\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\marck\anaconda3\envs\ML\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
Size=(176,176)
work_dr = ImageDataGenerator(
    rescale=1./255,
    rotation_range=10,
    shear_range=0.2,
    horizontal_flip=True,
    vertical_flip=True
)
# enhancing model generalization
train_data_gen = work_dr.flow_from_dataframe(df,x_col='image',y_col='label', target_size=Size, batch_size=6500, shuffle=False)
# Out:
# Found 6400 validated image filenames belonging to 4 classes.

# %%
train_data, train_labels = train_data_gen.next()

# %%
sm = SMOTE(random_state=42)
train_data, train_labels = sm.fit_resample(train_data.reshape(-1, 176 * 176 * 3), train_labels)
train_data = train_data.reshape(-1, 176,176, 3)
print(train_data.shape, train_labels.shape)
# Out:
# (12800, 176, 176, 3) (12800, 4)

# %%
original_labels = np.argmax(train_labels, axis=1)
df_resampled = pd.DataFrame({'label': original_labels})
class_counts_resampled = df_resampled['label'].value_counts()

# %%
labels = ['MildDemented','ModerateDemented','NonDemented','VeryMildDemented']
sizes = class_counts_resampled.values

assert len(labels) == len(sizes), "Length mismatch between labels and sizes"

class_distribution_table = pd.DataFrame({'Class': labels, 'Count': sizes})

plt.figure(figsize=(6, 4))
table = plt.table(cellText=class_distribution_table.values,
                  colLabels=class_distribution_table.columns,
                  cellLoc='center', loc='center', bbox=[0, 0, 1, 1])

table.auto_set_font_size(False)
table.set_fontsize(12)
table.scale(1.2, 1.2) 

for (i, j), cell in table.get_celld().items():
    if i == 0:
        cell.set_text_props(fontweight='bold')

plt.axis('off')
plt.title('Class Distribution after SMOTE', fontsize=16)
plt.show()

# %%
X_train, X_test1, y_train, y_test1 = train_test_split(train_data,train_labels, test_size=0.3, random_state=42,shuffle=True,stratify=train_labels)
X_val, X_test, y_val, y_test = train_test_split(X_test1,y_test1, test_size=0.5, random_state=42,shuffle=True,stratify=y_test1)
print('X_train shape is ' , X_train.shape)
print('X_test shape is ' , X_test.shape)
print('X_val shape is ' , X_val.shape)
print('y_train shape is ' , y_train.shape)
print('y_test shape is ' , y_test.shape)
print('y_val shape is ' , y_val.shape)
# Out:
# X_train shape is  (8960, 176, 176, 3)
# X_test shape is  (1920, 176, 176, 3)
# X_val shape is  (1920, 176, 176, 3)
# y_train shape is  (8960, 4)
# y_test shape is  (1920, 4)
# y_val shape is  (1920, 4)

# %%
plt.figure(figsize=(12, 6))
for i in range(5):
    plt.subplot(2, 5, i + 1)
    plt.imshow(X_train[i])
    plt.title(f'Augmented\n{class_num[np.argmax(y_train[i])]}')
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Models**

# %% [markdown]
# # InceptionV3

# %%
base_model = tf.keras.applications.InceptionV3(input_shape=(176,176,3),include_top=False,weights='imagenet')
base_model.trainable = False
model_Inception=keras.models.Sequential()
model_Inception.add(base_model)
model_Inception.add(keras.layers.Dropout(.5))
model_Inception.add(keras.layers.GlobalAveragePooling2D()) 
model_Inception.add(keras.layers.Flatten()) 
model_Inception.add(keras.layers.BatchNormalization())
model_Inception.add(keras.layers.Dense(512,activation=tf.nn.relu))
model_Inception.add(keras.layers.BatchNormalization())
model_Inception.add(keras.layers.Dropout(.5))
model_Inception.add(keras.layers.Dense(256,activation=tf.nn.relu))
model_Inception.add(keras.layers.BatchNormalization())
model_Inception.add(keras.layers.Dropout(.5))
model_Inception.add(keras.layers.Dense(128,activation=tf.nn.relu))
model_Inception.add(keras.layers.BatchNormalization())
model_Inception.add(keras.layers.Dropout(.5))
model_Inception.add(keras.layers.Dense(64,activation=tf.nn.relu))
model_Inception.add(keras.layers.BatchNormalization())
model_Inception.add(keras.layers.Dropout(.5))
model_Inception.add(keras.layers.BatchNormalization())
model_Inception.add(keras.layers.Dense(4, activation=tf.nn.softmax))
model_Inception.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 4, 4, 2048)        21802784
#
#  dropout (Dropout)           (None, 4, 4, 2048)        0
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  batch_normalization_94 (Bat  (None, 2048)             8192
#  chNormalization)
#
#  dense (Dense)               (None, 512)               1049088
#
#  batch_normalization_95 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  batch_normalization_96 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  batch_normalization_97 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  batch_normalization_98 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  batch_normalization_99 (Bat  (None, 64)               256
#  chNormalization)
#
#  dense_4 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 23,036,900
# Trainable params: 1,227,972
# Non-trainable params: 21,808,928
# _________________________________________________________________

# %%
checkpoint_cb = ModelCheckpoint("inception.h5", save_best_only=True)
early_stopping_cb = EarlyStopping(patience=10, restore_best_weights=True)

optimizer_rmsprop = RMSprop(learning_rate=0.001)  # You can adjust the learning rate if needed
model_Inception.compile(optimizer=optimizer_rmsprop, loss='categorical_crossentropy', metrics=['accuracy'])
hist = model_Inception.fit(X_train, y_train, epochs=50, validation_data=(X_val, y_val), callbacks=[checkpoint_cb, early_stopping_cb], batch_size=256)
# Out:
# Epoch 1/50
# 35/35 [==============================] - 138s 4s/step - loss: 1.4177 - accuracy: 0.3915 - val_loss: 2.4465 - val_accuracy: 0.3479
# Epoch 2/50
# 35/35 [==============================] - 128s 4s/step - loss: 1.0315 - accuracy: 0.5297 - val_loss: 1.6370 - val_accuracy: 0.4995
# Epoch 3/50
# 35/35 [==============================] - 127s 4s/step - loss: 0.8786 - accuracy: 0.5896 - val_loss: 1.0376 - val_accuracy: 0.6005
# Epoch 4/50
# 35/35 [==============================] - 125s 4s/step - loss: 0.7829 - accuracy: 0.6305 - val_loss: 0.7791 - val_accuracy: 0.6573
# Epoch 5/50
# 35/35 [==============================] - 125s 4s/step - loss: 0.7347 - accuracy: 0.6513 - val_loss: 0.6629 - val_accuracy: 0.6833
# Epoch 6/50
# 35/35 [==============================] - 124s 4s/step - loss: 0.6865 - accuracy: 0.6757 - val_loss: 0.6525 - val_accuracy: 0.6927
# Epoch 7/50
# 35/35 [==============================] - 124s 4s/step - loss: 0.6603 - accuracy: 0.6877 - val_loss: 0.6162 - val_accuracy: 0.7036
# Epoch 8/50
# 35/35 [==============================] - 123s 4s/step - loss: 0.6293 - accuracy: 0.7050 - val_loss: 0.6155 - val_accuracy: 0.7073
# Epoch 9/50
# 35/35 [==============================] - 123s 4s/step - loss: 0.6103 - accuracy: 0.7193 - val_loss: 0.5945 - val_accuracy: 0.7234
# Epoch 10/50
# 35/35 [==============================] - 123s 4s/step - loss: 0.5941 - accuracy: 0.7268 - val_loss: 0.6031 - val_accuracy: 0.7135
# Epoch 11/50
# 35/35 [==============================] - 123s 4s/step - loss: 0.5704 - accuracy: 0.7392 - val_loss: 0.6040 - val_accuracy: 0.7307
# Epoch 12/50
# 35/35 [==============================] - 128s 4s/step - loss: 0.5446 - accuracy: 0.7516 - val_loss: 0.5516 - val_accuracy: 0.7568
# Epoch 13/50
# 35/35 [==============================] - 124s 4s/step - loss: 0.5368 - accuracy: 0.7633 - val_loss: 0.5382 - val_accuracy: 0.7609
# Epoch 14/50
# 35/35 [==============================] - 123s 4s/step - loss: 0.4983 - accuracy: 0.7856 - val_loss: 0.5383 - val_accuracy: 0.7505
# Epoch 15/50
# 35/35 [==============================] - 124s 4s/step - loss: 0.4865 - accuracy: 0.7901 - val_loss: 0.5109 - val_accuracy: 0.7755
# Epoch 16/50
# 35/35 [==============================] - 124s 4s/step - loss: 0.4701 - accuracy: 0.7972 - val_loss: 0.5394 - val_accuracy: 0.7667
# Epoch 17/50
# 35/35 [==============================] - 123s 4s/step - loss: 0.4467 - accuracy: 0.8153 - val_loss: 0.5650 - val_accuracy: 0.7594
# Epoch 18/50
# 35/35 [==============================] - 123s 4s/step - loss: 0.4352 - accuracy: 0.8192 - val_loss: 0.4876 - val_accuracy: 0.7859
# Epoch 19/50
# 35/35 [==============================] - 126s 4s/step - loss: 0.4174 - accuracy: 0.8253 - val_loss: 0.4734 - val_accuracy: 0.7979
# Epoch 20/50
# 35/35 [==============================] - 124s 4s/step - loss: 0.3986 - accuracy: 0.8373 - val_loss: 0.4927 - val_accuracy: 0.7865
# Epoch 21/50
# 35/35 [==============================] - 126s 4s/step - loss: 0.3900 - accuracy: 0.8377 - val_loss: 0.4543 - val_accuracy: 0.8062
# Epoch 22/50
# 35/35 [==============================] - 123s 4s/step - loss: 0.3695 - accuracy: 0.8539 - val_loss: 0.4369 - val_accuracy: 0.8151
# Epoch 23/50
# 35/35 [==============================] - 124s 4s/step - loss: 0.3537 - accuracy: 0.8593 - val_loss: 0.4458 - val_accuracy: 0.8083
# Epoch 24/50
# 35/35 [==============================] - 123s 4s/step - loss: 0.3493 - accuracy: 0.8598 - val_loss: 0.4530 - val_accuracy: 0.8125
# Epoch 25/50
# 35/35 [==============================] - 123s 4s/step - loss: 0.3262 - accuracy: 0.8694 - val_loss: 0.4673 - val_accuracy: 0.8094
# Epoch 26/50
# 35/35 [==============================] - 123s 4s/step - loss: 0.3140 - accuracy: 0.8768 - val_loss: 0.4676 - val_accuracy: 0.8203
# Epoch 27/50
# 35/35 [==============================] - 124s 4s/step - loss: 0.3042 - accuracy: 0.8807 - val_loss: 0.4595 - val_accuracy: 0.8224
# Epoch 28/50
# 35/35 [==============================] - 123s 4s/step - loss: 0.2888 - accuracy: 0.8864 - val_loss: 0.4547 - val_accuracy: 0.8208
# Epoch 29/50
# 35/35 [==============================] - 124s 4s/step - loss: 0.2882 - accuracy: 0.8914 - val_loss: 0.4674 - val_accuracy: 0.8229
# Epoch 30/50
# 35/35 [==============================] - 123s 4s/step - loss: 0.2617 - accuracy: 0.9021 - val_loss: 0.4509 - val_accuracy: 0.8286
# Epoch 31/50
# 35/35 [==============================] - 123s 4s/step - loss: 0.2761 - accuracy: 0.8962 - val_loss: 0.4564 - val_accuracy: 0.8245
# Epoch 32/50
# 35/35 [==============================] - 123s 4s/step - loss: 0.2532 - accuracy: 0.9069 - val_loss: 0.4691 - val_accuracy: 0.8234

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(hist.history['loss'], label='Train')
plt.plot(hist.history['val_loss'], label='Validation')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(hist.history['accuracy'], label='Train')
plt.plot(hist.history['val_accuracy'], label='Validation')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
y_pred = model_Inception.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Calculate the confusion matrix
conf_mat = confusion_matrix(y_true_classes, y_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues', xticklabels=class_num, yticklabels=class_num)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 y_pred = model_Inception.predict(X_test)
#       2 y_pred_classes = np.argmax(y_pred, axis=1)
#       3 y_true_classes = np.argmax(y_test, axis=1)
#
# NameError: name 'model_Inception' is not defined

# %%
score, acc= model_Inception.evaluate(X_test,y_test)
print('Test Loss =', score)
print('Test Accuracy =', acc)
# Out:
# 60/60 [==============================] - 26s 429ms/step - loss: 0.4627 - accuracy: 0.8146
# Test Loss = 0.46267712116241455
# Test Accuracy = 0.8145833611488342

# %% [markdown]
# # Resnet50 approach

# %%
# Load ResNet50 model with pre-trained weights (excluding the top layer)
base_model_resnet = ResNet50(weights='imagenet', include_top=False, input_shape=(176, 176, 3))

# Freeze the layers of the pre-trained model
for layer in base_model_resnet.layers:
    layer.trainable = False

# Create a new model by adding custom layers on top of the pre-trained ResNet50
model_resnet = Sequential([
    base_model_resnet,
    Dropout(0.5),
    GlobalAveragePooling2D(),
    Flatten(),
    BatchNormalization(),
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    BatchNormalization(),
    Dense(4, activation='softmax')
])

# Display the model summary
model_resnet.summary()

# Compile the model
optimizer_rmsprop = RMSprop(learning_rate=0.001)
model_resnet.compile(optimizer=optimizer_rmsprop, loss='categorical_crossentropy', metrics=['accuracy'])

# Set up callbacks for model training
checkpoint_cb_resnet = ModelCheckpoint("resnet.h5", save_best_only=True)
early_stopping_cb_resnet = EarlyStopping(patience=10, restore_best_weights=True)

# Train the model
hist_resnet = model_resnet.fit(X_train, y_train, epochs=50, validation_data=(X_val, y_val),
                               callbacks=[checkpoint_cb_resnet, early_stopping_cb_resnet], batch_size=256)

# Evaluate the model
score_resnet, acc_resnet = model_resnet.evaluate(X_test, y_test)
print('Test Loss =', score_resnet)
print('Test Accuracy =', acc_resnet)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 6, 6, 2048)        23587712
#
#  dropout_5 (Dropout)         (None, 6, 6, 2048)        0
#
#  global_average_pooling2d_1   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  batch_normalization_100 (Ba  (None, 2048)             8192
#  tchNormalization)
#
#  dense_5 (Dense)             (None, 512)               1049088
#
#  batch_normalization_101 (Ba  (None, 512)              2048
#  tchNormalization)
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  dense_6 (Dense)             (None, 256)               131328
#
#  batch_normalization_102 (Ba  (None, 256)              1024
#  tchNormalization)
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  batch_normalization_103 (Ba  (None, 128)              512
#  tchNormalization)
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  batch_normalization_104 (Ba  (None, 64)               256
#  tchNormalization)
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  batch_normalization_105 (Ba  (None, 64)               256
#  tchNormalization)
#
#  dense_9 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 24,821,828
# Trainable params: 1,227,972
# Non-trainable params: 23,593,856
# _________________________________________________________________
# Epoch 1/50
# 35/35 [==============================] - 238s 7s/step - loss: 1.6360 - accuracy: 0.2890 - val_loss: 1.3817 - val_accuracy: 0.2505
# Epoch 2/50
# 35/35 [==============================] - 232s 7s/step - loss: 1.4526 - accuracy: 0.3430 - val_loss: 1.3770 - val_accuracy: 0.2531
# Epoch 3/50
# 35/35 [==============================] - 232s 7s/step - loss: 1.3244 - accuracy: 0.3914 - val_loss: 1.3819 - val_accuracy: 0.2594
# Epoch 4/50
# 35/35 [==============================] - 232s 7s/step - loss: 1.2372 - accuracy: 0.4192 - val_loss: 1.3358 - val_accuracy: 0.3234
# Epoch 5/50
# 35/35 [==============================] - 233s 7s/step - loss: 1.1634 - accuracy: 0.4561 - val_loss: 1.2473 - val_accuracy: 0.3833
# Epoch 6/50
# 35/35 [==============================] - 232s 7s/step - loss: 1.1197 - accuracy: 0.4806 - val_loss: 1.2067 - val_accuracy: 0.4026
# Epoch 7/50
# 35/35 [==============================] - 232s 7s/step - loss: 1.0870 - accuracy: 0.4964 - val_loss: 1.2330 - val_accuracy: 0.3594
# Epoch 8/50
# 35/35 [==============================] - 234s 7s/step - loss: 1.0500 - accuracy: 0.5223 - val_loss: 1.2209 - val_accuracy: 0.3625
# Epoch 9/50
# 35/35 [==============================] - 232s 7s/step - loss: 1.0300 - accuracy: 0.5267 - val_loss: 1.1651 - val_accuracy: 0.4432
# Epoch 10/50
# 35/35 [==============================] - 235s 7s/step - loss: 1.0128 - accuracy: 0.5426 - val_loss: 1.1451 - val_accuracy: 0.4411
# Epoch 11/50
# 35/35 [==============================] - 235s 7s/step - loss: 0.9904 - accuracy: 0.5467 - val_loss: 1.0574 - val_accuracy: 0.4880
# Epoch 12/50
# 35/35 [==============================] - 233s 7s/step - loss: 0.9683 - accuracy: 0.5656 - val_loss: 1.0105 - val_accuracy: 0.5479
# Epoch 13/50
# 35/35 [==============================] - 234s 7s/step - loss: 0.9564 - accuracy: 0.5689 - val_loss: 0.9683 - val_accuracy: 0.5661
# Epoch 14/50
# 35/35 [==============================] - 236s 7s/step - loss: 0.9472 - accuracy: 0.5742 - val_loss: 0.9541 - val_accuracy: 0.5682
# Epoch 15/50
# 35/35 [==============================] - 233s 7s/step - loss: 0.9319 - accuracy: 0.5781 - val_loss: 0.8509 - val_accuracy: 0.6333
# Epoch 16/50
# 35/35 [==============================] - 238s 7s/step - loss: 0.9315 - accuracy: 0.5795 - val_loss: 0.8164 - val_accuracy: 0.6474
# Epoch 17/50
# 35/35 [==============================] - 242s 7s/step - loss: 0.9103 - accuracy: 0.5919 - val_loss: 0.7958 - val_accuracy: 0.6495
# Epoch 18/50
# 35/35 [==============================] - 233s 7s/step - loss: 0.9123 - accuracy: 0.5879 - val_loss: 0.7873 - val_accuracy: 0.6474
# Epoch 19/50
# 35/35 [==============================] - 235s 7s/step - loss: 0.9038 - accuracy: 0.5905 - val_loss: 0.7911 - val_accuracy: 0.6359
# Epoch 20/50
# 35/35 [==============================] - 232s 7s/step - loss: 0.8972 - accuracy: 0.5922 - val_loss: 0.7678 - val_accuracy: 0.6359
# Epoch 21/50
# 35/35 [==============================] - 234s 7s/step - loss: 0.8810 - accuracy: 0.6010 - val_loss: 0.7567 - val_accuracy: 0.6474
# Epoch 22/50
# 35/35 [==============================] - 234s 7s/step - loss: 0.8751 - accuracy: 0.6006 - val_loss: 0.7490 - val_accuracy: 0.6578
# Epoch 23/50
# 35/35 [==============================] - 235s 7s/step - loss: 0.8895 - accuracy: 0.6010 - val_loss: 0.7498 - val_accuracy: 0.6526
# Epoch 24/50
# 35/35 [==============================] - 234s 7s/step - loss: 0.8665 - accuracy: 0.6045 - val_loss: 0.7351 - val_accuracy: 0.6573
# Epoch 25/50
# 35/35 [==============================] - 234s 7s/step - loss: 0.8667 - accuracy: 0.6095 - val_loss: 0.7252 - val_accuracy: 0.6552
# Epoch 26/50
# 35/35 [==============================] - 236s 7s/step - loss: 0.8632 - accuracy: 0.6035 - val_loss: 0.7137 - val_accuracy: 0.6708
# Epoch 27/50
# 35/35 [==============================] - 235s 7s/step - loss: 0.8526 - accuracy: 0.6125 - val_loss: 0.7042 - val_accuracy: 0.6604
# Epoch 28/50
# 35/35 [==============================] - 235s 7s/step - loss: 0.8567 - accuracy: 0.6121 - val_loss: 0.7049 - val_accuracy: 0.6656
# Epoch 29/50
# 35/35 [==============================] - 235s 7s/step - loss: 0.8472 - accuracy: 0.6073 - val_loss: 0.7087 - val_accuracy: 0.6656
# Epoch 30/50
# 35/35 [==============================] - 237s 7s/step - loss: 0.8471 - accuracy: 0.6110 - val_loss: 0.7013 - val_accuracy: 0.6651
# Epoch 31/50
# 35/35 [==============================] - 236s 7s/step - loss: 0.8430 - accuracy: 0.6174 - val_loss: 0.7052 - val_accuracy: 0.6630
# Epoch 32/50
# 35/35 [==============================] - 238s 7s/step - loss: 0.8383 - accuracy: 0.6150 - val_loss: 0.7198 - val_accuracy: 0.6505
# Epoch 33/50
# 35/35 [==============================] - 236s 7s/step - loss: 0.8261 - accuracy: 0.6214 - val_loss: 0.6982 - val_accuracy: 0.6651
# Epoch 34/50
# 35/35 [==============================] - 237s 7s/step - loss: 0.8156 - accuracy: 0.6309 - val_loss: 0.6932 - val_accuracy: 0.6677
# Epoch 35/50
# 35/35 [==============================] - 237s 7s/step - loss: 0.8164 - accuracy: 0.6285 - val_loss: 0.6848 - val_accuracy: 0.6703
# Epoch 36/50
# 35/35 [==============================] - 235s 7s/step - loss: 0.8193 - accuracy: 0.6214 - val_loss: 0.6976 - val_accuracy: 0.6693
# Epoch 37/50
# 35/35 [==============================] - 236s 7s/step - loss: 0.8263 - accuracy: 0.6190 - val_loss: 0.6927 - val_accuracy: 0.6708
# Epoch 38/50
# 35/35 [==============================] - 237s 7s/step - loss: 0.8068 - accuracy: 0.6276 - val_loss: 0.6923 - val_accuracy: 0.6734
# Epoch 39/50
# 35/35 [==============================] - 236s 7s/step - loss: 0.8038 - accuracy: 0.6315 - val_loss: 0.6970 - val_accuracy: 0.6651
# Epoch 40/50
# 35/35 [==============================] - 236s 7s/step - loss: 0.7936 - accuracy: 0.6291 - val_loss: 0.6792 - val_accuracy: 0.6771
# Epoch 41/50
# 35/35 [==============================] - 235s 7s/step - loss: 0.8010 - accuracy: 0.6291 - val_loss: 0.6731 - val_accuracy: 0.6839
# Epoch 42/50
# 35/35 [==============================] - 237s 7s/step - loss: 0.7975 - accuracy: 0.6377 - val_loss: 0.6623 - val_accuracy: 0.6865
# Epoch 43/50
# 35/35 [==============================] - 236s 7s/step - loss: 0.7997 - accuracy: 0.6344 - val_loss: 0.6765 - val_accuracy: 0.6812
# Epoch 44/50
# 35/35 [==============================] - 236s 7s/step - loss: 0.7951 - accuracy: 0.6365 - val_loss: 0.6666 - val_accuracy: 0.6760
# Epoch 45/50
# 35/35 [==============================] - 236s 7s/step - loss: 0.7884 - accuracy: 0.6372 - val_loss: 0.6723 - val_accuracy: 0.6781
# Epoch 46/50
# 35/35 [==============================] - 237s 7s/step - loss: 0.7859 - accuracy: 0.6388 - val_loss: 0.6743 - val_accuracy: 0.6807
# Epoch 47/50
# 35/35 [==============================] - 237s 7s/step - loss: 0.7763 - accuracy: 0.6446 - val_loss: 0.6593 - val_accuracy: 0.6807
# Epoch 48/50
# 35/35 [==============================] - 237s 7s/step - loss: 0.7764 - accuracy: 0.6434 - val_loss: 0.6533 - val_accuracy: 0.6927
# Epoch 49/50
# 35/35 [==============================] - 237s 7s/step - loss: 0.7684 - accuracy: 0.6451 - val_loss: 0.6585 - val_accuracy: 0.6854
# Epoch 50/50
# 35/35 [==============================] - 238s 7s/step - loss: 0.7673 - accuracy: 0.6463 - val_loss: 0.6733 - val_accuracy: 0.6750
# 60/60 [==============================] - 48s 798ms/step - loss: 0.6732 - accuracy: 0.6911
# Test Loss = 0.6732279062271118
# Test Accuracy = 0.6911458373069763
